# %%
import numpy as np 
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1fd6a7d21533> in <module>
# ----> 1 import numpy as np
#       2 import pandas as pd
#       3 from mlxtend.frequent_patterns import apriori, association_rules
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import numpy as np 
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1fd6a7d21533> in <module>
#       1 import numpy as np
# ----> 2 import pandas as pd
#       3 from mlxtend.frequent_patterns import apriori, association_rules
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import numpy as np 
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1fd6a7d21533> in <module>
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 from mlxtend.frequent_patterns import apriori, association_rules
#
# ModuleNotFoundError: No module named 'mlxtend'

# %%
import numpy as np 
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %%
data = pd.read_excel('Online_Retail.xlsx') 
data.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-7cc944a5f119> in <module>
# ----> 1 data = pd.read_excel('Online_Retail.xlsx')
#       2 data.head()
#
# c:\users\owner\desktop\python\new notebook\env\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# c:\users\owner\desktop\python\new notebook\env\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols)
#     302
# ...

# %%
data = pd.read_excel('Online_Retail.xlsx') 
data.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-7cc944a5f119> in <module>
# ----> 1 data = pd.read_excel('Online_Retail.xlsx')
#       2 data.head()
#
# c:\users\owner\desktop\python\new notebook\env\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# c:\users\owner\desktop\python\new notebook\env\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols)
#     302
# ...

# %%
data = pd.read_excel('https://github.com/Sushek69/Online-Retail/blob/master/Online%20Retail.csv') 
data.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-8cb6b408c463> in <module>
# ----> 1 data = pd.read_excel('https://github.com/Sushek69/Online-Retail/blob/master/Online%20Retail.csv')
#       2 data.head()
#
# c:\users\owner\desktop\python\new notebook\env\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ...

# %%
data = pd.read_excel('https://github.com/Sushek69/Online-Retail/blob/master/Online%20Retail.csv') 
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8cb6b408c463> in <module>
# ----> 1 data = pd.read_excel('https://github.com/Sushek69/Online-Retail/blob/master/Online%20Retail.csv')
#       2 data.head()
#
# NameError: name 'pd' is not defined

# %%
import numpy as np 
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %%
data = pd.read_excel('https://github.com/Sushek69/Online-Retail/blob/master/Online%20Retail.csv') 
data.head()
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-3-37b6780d1ab9> in <module>
# ----> 1 data = pd.read_excel('https://github.com/Sushek69/Online-Retail/blob/master/Online%20Retail.csv')
#       2 data.head()
#
# c:\users\owner\desktop\python\new notebook\env\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ...

# %%
data = pd.read_excel('https://github.com/Sushek69/Online-Retail/blob/master/Online%20Retail.xlsx') 
data.head()
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-4-f1e2c5fa4909> in <module>
# ----> 1 data = pd.read_excel('https://github.com/Sushek69/Online-Retail/blob/master/Online%20Retail.xlsx')
#       2 data.head()
#
# c:\users\owner\desktop\python\new notebook\env\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ...

# %%
data = pd.read_excel('Online_Retail.xlsx') 
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-7cc944a5f119> in <module>
# ----> 1 data = pd.read_excel('Online_Retail.xlsx')
#       2 data.head()
#
# c:\users\owner\desktop\python\new notebook\env\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# c:\users\owner\desktop\python\new notebook\env\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols)
#     302
# ...

# %%
url = 'https://github.com/Sushek69/Online-Retail/blob/master/Online%20Retail.xlsx'

# %%
df1 = pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-24-3bc64550bc1d> in <module>
# ----> 1 df1 = pd.read_csv(url)
#
# c:\users\owner\desktop\python\new notebook\env\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Owner\\Desktop\\Python\\new notebook'
